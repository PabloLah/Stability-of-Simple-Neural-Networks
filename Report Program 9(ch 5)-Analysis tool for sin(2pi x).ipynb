# %%
#Note: We program a simple NN to interpolate a linear function.


#generating random data from a linear function and adding noise
#generate x-values uniformly inside the interval [0,1]
import numpy as np
X_data = np.random.uniform(0, 1, 1000)

#generate values of the function f(x) = x^2
y_data = np.sin(2*np.pi*X_data)


#building the model
#import the necessary functions from the tensorflow library
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import initializers

#build the model with 2^N nodes in one hidden layer.
N=4

model = Sequential()
model.add(Dense(2**N, input_dim=1, activation='relu', use_bias=True))
model.add(Dense(1, activation='linear', use_bias=False))


#compile the model
model.compile(loss='mean_squared_error', optimizer='SGD')

#fit the model to our data
model.fit(X_data, y_data, epochs=400, batch_size=20)


#evaluate the model
predictions = model.predict(X_data)

#now note that y_data is a row vector, while predictions is a column vector. So first we have to adjust the format:
#y_data = [.. , .. , .. , ...]  while 
#predictions = [[..],[..],[..], ...]

#let predictions have the same format as y_data
[predictions] = predictions.transpose()

import matplotlib.pyplot as plt

plt.clf()
plt.plot(X_data,y_data,'.')
plt.plot(X_data,predictions,'.')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.show()


#if you are interested, here is some cod which I used to further analyze the weights of the NN:

#get the weights of the NN
#optimized_weights = model.get_weights()

#note: There are 4 blocks of variables (one for every type of weight); in every block there are as many weights 
#as there are nodes
#for a node i we have alpha_i * ReLU(beta_i * x + b_i) + h_i (for i=0 to 2^n-1)

#block 0: all beta_i = optimized_weights[0][0][i]
#block 1: all b_i (bias of the first step in NN) = optimized_weights[1][i]
#block 2: all alpha_i = optimized_weights[2][i][0]
#CURRENTLY NOT ACTIVATED: block 3: all h_i = optimized_weights[3][i]
#print(model.get_weights())
# Out:
# Epoch 1/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4887
# Epoch 2/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4253
# Epoch 3/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.3869
# Epoch 4/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.3569
# Epoch 5/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.3329
# Epoch 6/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.3121
# Epoch 7/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.2928
# Epoch 8/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.2748
# Epoch 9/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.2572
# Epoch 10/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.2413
# Epoch 11/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.2256
# Epoch 12/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.2125
# Epoch 13/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.2011
# Epoch 14/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1917
# Epoch 15/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1838
# Epoch 16/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1780
# Epoch 17/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1739
# Epoch 18/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1708
# Epoch 19/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1679
# Epoch 20/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1661
# Epoch 21/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1651
# Epoch 22/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1643
# Epoch 23/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1638
# Epoch 24/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1631
# Epoch 25/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1631
# Epoch 26/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1626
# Epoch 27/400
# 50/50 [==============================] - 0s 998us/step - loss: 0.1624
# Epoch 28/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.1627
# Epoch 29/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1626
# Epoch 30/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.1621
# Epoch 31/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1619
# Epoch 32/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1618
# Epoch 33/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1623A: 0s - loss: 0.163
# Epoch 34/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1620
# Epoch 35/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1612
# Epoch 36/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1616
# Epoch 37/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1620
# Epoch 38/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1619
# Epoch 39/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1620
# Epoch 40/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1618
# Epoch 41/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1615
# Epoch 42/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1615
# Epoch 43/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1622
# Epoch 44/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1616
# Epoch 45/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1615
# Epoch 46/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1620
# Epoch 47/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1619
# Epoch 48/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1618
# Epoch 49/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1615
# Epoch 50/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1614
# Epoch 51/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1614
# Epoch 52/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1618
# Epoch 53/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1613
# Epoch 54/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1611
# Epoch 55/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1612
# Epoch 56/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1613
# Epoch 57/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1613
# Epoch 58/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1613
# Epoch 59/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1614
# Epoch 60/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1615
# Epoch 61/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1610
# Epoch 62/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1613
# Epoch 63/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1613
# Epoch 64/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1607
# Epoch 65/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1610
# Epoch 66/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1612
# Epoch 67/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1610
# Epoch 68/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1610
# Epoch 69/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1614
# Epoch 70/400
# 50/50 [==============================] - 0s 965us/step - loss: 0.1608
# Epoch 71/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1607
# Epoch 72/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1605
# Epoch 73/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1610
# Epoch 74/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1606
# Epoch 75/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1607
# Epoch 76/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1607
# Epoch 77/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1611
# Epoch 78/400
# 50/50 [==============================] - 0s 912us/step - loss: 0.1605
# Epoch 79/400
# 50/50 [==============================] - 0s 939us/step - loss: 0.1605
# Epoch 80/400
# 50/50 [==============================] - 0s 959us/step - loss: 0.1604
# Epoch 81/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1603
# Epoch 82/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1605
# Epoch 83/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1603
# Epoch 84/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1606
# Epoch 85/400
# 50/50 [==============================] - 0s 887us/step - loss: 0.1605
# Epoch 86/400
# 50/50 [==============================] - 0s 868us/step - loss: 0.1606
# Epoch 87/400
# 50/50 [==============================] - 0s 921us/step - loss: 0.1604
# Epoch 88/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1596
# Epoch 89/400
# 50/50 [==============================] - 0s 922us/step - loss: 0.1604
# Epoch 90/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.1598
# Epoch 91/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1605
# Epoch 92/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1602
# Epoch 93/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1601
# Epoch 94/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.1601
# Epoch 95/400
# 50/50 [==============================] - 0s 912us/step - loss: 0.1601
# Epoch 96/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1600
# Epoch 97/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1598
# Epoch 98/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1597
# Epoch 99/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1598
# Epoch 100/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1596
# Epoch 101/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1597
# Epoch 102/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1594
# Epoch 103/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1595
# Epoch 104/400
# 50/50 [==============================] - 0s 898us/step - loss: 0.1592
# Epoch 105/400
# 50/50 [==============================] - 0s 910us/step - loss: 0.1594
# Epoch 106/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1592
# Epoch 107/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1592
# Epoch 108/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1594
# Epoch 109/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1588
# Epoch 110/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1595A: 0s - loss: 0.15
# Epoch 111/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1595A: 0s - loss: 0.162
# Epoch 112/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1590
# Epoch 113/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1593
# Epoch 114/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1589
# Epoch 115/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1585
# Epoch 116/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1594
# Epoch 117/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1589
# Epoch 118/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1585
# Epoch 119/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1587
# Epoch 120/400
# 50/50 [==============================] - 0s 881us/step - loss: 0.1584
# Epoch 121/400
# 50/50 [==============================] - 0s 919us/step - loss: 0.1588
# Epoch 122/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1572
# Epoch 123/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1583
# Epoch 124/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1584
# Epoch 125/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1584
# Epoch 126/400
# 50/50 [==============================] - 0s 999us/step - loss: 0.1582
# Epoch 127/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1579
# Epoch 128/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1581
# Epoch 129/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.1578
# Epoch 130/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1580
# Epoch 131/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1578
# Epoch 132/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1578
# Epoch 133/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1570
# Epoch 134/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1578
# Epoch 135/400
# 50/50 [==============================] - 0s 985us/step - loss: 0.1582
# Epoch 136/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1572
# Epoch 137/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1579
# Epoch 138/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1575
# Epoch 139/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1571
# Epoch 140/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1569
# Epoch 141/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1568
# Epoch 142/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1569
# Epoch 143/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1571
# Epoch 144/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1569
# Epoch 145/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1562
# Epoch 146/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1566
# Epoch 147/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1567
# Epoch 148/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1562
# Epoch 149/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1565
# Epoch 150/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1563
# Epoch 151/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1560
# Epoch 152/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1558
# Epoch 153/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1561
# Epoch 154/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1553
# Epoch 155/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1547
# Epoch 156/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1555
# Epoch 157/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1558
# Epoch 158/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1556
# Epoch 159/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1552
# Epoch 160/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1550
# Epoch 161/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1549
# Epoch 162/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1541
# Epoch 163/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1544
# Epoch 164/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1547
# Epoch 165/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1547
# Epoch 166/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1542
# Epoch 167/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1541
# Epoch 168/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1542
# Epoch 169/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1533
# Epoch 170/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1534
# Epoch 171/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1530
# Epoch 172/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1533
# Epoch 173/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1529
# Epoch 174/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1520
# Epoch 175/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1531
# Epoch 176/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1526
# Epoch 177/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1529
# Epoch 178/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1524
# Epoch 179/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1523
# Epoch 180/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1516
# Epoch 181/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1511
# Epoch 182/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1521
# Epoch 183/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1501
# Epoch 184/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1509
# Epoch 185/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1507
# Epoch 186/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1505
# Epoch 187/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1500
# Epoch 188/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1500
# Epoch 189/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1498
# Epoch 190/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1499
# Epoch 191/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1492
# Epoch 192/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1485
# Epoch 193/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1490
# Epoch 194/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1479
# Epoch 195/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1485
# Epoch 196/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1483
# Epoch 197/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1478
# Epoch 198/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1476
# Epoch 199/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1472
# Epoch 200/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1472
# Epoch 201/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1467
# Epoch 202/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1464
# Epoch 203/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1455
# Epoch 204/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1454
# Epoch 205/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1452
# Epoch 206/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1451
# Epoch 207/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1450
# Epoch 208/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1443
# Epoch 209/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1439
# Epoch 210/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1433
# Epoch 211/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1434
# Epoch 212/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1419
# Epoch 213/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.1426
# Epoch 214/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1417
# Epoch 215/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1419
# Epoch 216/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1408
# Epoch 217/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1406
# Epoch 218/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1409
# Epoch 219/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1403
# Epoch 220/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1396
# Epoch 221/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1386
# Epoch 222/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1386
# Epoch 223/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1383
# Epoch 224/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1378
# Epoch 225/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1377
# Epoch 226/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1356
# Epoch 227/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1361
# Epoch 228/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1361
# Epoch 229/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1352
# Epoch 230/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1345
# Epoch 231/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1333
# Epoch 232/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1339A: 0s - loss: 0.134
# Epoch 233/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1338
# Epoch 234/400
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1321
# Epoch 235/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1318
# Epoch 236/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1307
# Epoch 237/400
# 50/50 [==============================] - 0s 875us/step - loss: 0.1306
# Epoch 238/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1300
# Epoch 239/400
# 50/50 [==============================] - 0s 834us/step - loss: 0.1298
# Epoch 240/400
# 50/50 [==============================] - 0s 887us/step - loss: 0.1286
# Epoch 241/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1280
# Epoch 242/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1274
# Epoch 243/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1268
# Epoch 244/400
# 50/50 [==============================] - 0s 997us/step - loss: 0.1258
# Epoch 245/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1257
# Epoch 246/400
# 50/50 [==============================] - 0s 875us/step - loss: 0.1247
# Epoch 247/400
# 50/50 [==============================] - 0s 934us/step - loss: 0.1242
# Epoch 248/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1232
# Epoch 249/400
# 50/50 [==============================] - 0s 887us/step - loss: 0.1229
# Epoch 250/400
# 50/50 [==============================] - 0s 871us/step - loss: 0.1220
# Epoch 251/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1211
# Epoch 252/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1207
# Epoch 253/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1196
# Epoch 254/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1185
# Epoch 255/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1180
# Epoch 256/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.1174
# Epoch 257/400
# 50/50 [==============================] - 0s 875us/step - loss: 0.1165
# Epoch 258/400
# 50/50 [==============================] - 0s 856us/step - loss: 0.1154
# Epoch 259/400
# 50/50 [==============================] - 0s 856us/step - loss: 0.1143
# Epoch 260/400
# 50/50 [==============================] - 0s 844us/step - loss: 0.1133
# Epoch 261/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1134
# Epoch 262/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1126
# Epoch 263/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1114
# Epoch 264/400
# 50/50 [==============================] - 0s 937us/step - loss: 0.1107
# Epoch 265/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1099
# Epoch 266/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1090
# Epoch 267/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1082
# Epoch 268/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1076
# Epoch 269/400
# 50/50 [==============================] - 0s 875us/step - loss: 0.1069
# Epoch 270/400
# 50/50 [==============================] - 0s 861us/step - loss: 0.1057
# Epoch 271/400
# 50/50 [==============================] - 0s 917us/step - loss: 0.1043
# Epoch 272/400
# 50/50 [==============================] - 0s 857us/step - loss: 0.1037
# Epoch 273/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1024
# Epoch 274/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.1024
# Epoch 275/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.1011
# Epoch 276/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.1004
# Epoch 277/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0992
# Epoch 278/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0989
# Epoch 279/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0974
# Epoch 280/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0970
# Epoch 281/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0958
# Epoch 282/400
# 50/50 [==============================] - 0s 827us/step - loss: 0.0947
# Epoch 283/400
# 50/50 [==============================] - 0s 937us/step - loss: 0.0941
# Epoch 284/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0931
# Epoch 285/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0920
# Epoch 286/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0912
# Epoch 287/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0903
# Epoch 288/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0893
# Epoch 289/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0884
# Epoch 290/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0876
# Epoch 291/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0862
# Epoch 292/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.0853
# Epoch 293/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0845
# Epoch 294/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0832
# Epoch 295/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0821
# Epoch 296/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0816
# Epoch 297/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0804
# Epoch 298/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0798
# Epoch 299/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0787
# Epoch 300/400
# 50/50 [==============================] - 0s 855us/step - loss: 0.0778
# Epoch 301/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0768
# Epoch 302/400
# 50/50 [==============================] - 0s 851us/step - loss: 0.0759
# Epoch 303/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0750
# Epoch 304/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0738
# Epoch 305/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0734
# Epoch 306/400
# 50/50 [==============================] - 0s 875us/step - loss: 0.0719
# Epoch 307/400
# 50/50 [==============================] - 0s 834us/step - loss: 0.0713
# Epoch 308/400
# 50/50 [==============================] - 0s 837us/step - loss: 0.0709
# Epoch 309/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0694
# Epoch 310/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0685
# Epoch 311/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0678
# Epoch 312/400
# 50/50 [==============================] - 0s 830us/step - loss: 0.0667
# Epoch 313/400
# 50/50 [==============================] - 0s 838us/step - loss: 0.0659
# Epoch 314/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0650
# Epoch 315/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0644
# Epoch 316/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0630
# Epoch 317/400
# 50/50 [==============================] - 0s 851us/step - loss: 0.0623
# Epoch 318/400
# 50/50 [==============================] - 0s 857us/step - loss: 0.0617
# Epoch 319/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0610
# Epoch 320/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0601
# Epoch 321/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0588
# Epoch 322/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0577
# Epoch 323/400
# 50/50 [==============================] - 0s 861us/step - loss: 0.0575
# Epoch 324/400
# 50/50 [==============================] - 0s 851us/step - loss: 0.0569
# Epoch 325/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0556
# Epoch 326/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0551
# Epoch 327/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0543
# Epoch 328/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.0533
# Epoch 329/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0528
# Epoch 330/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0521
# Epoch 331/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0513
# Epoch 332/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0504
# Epoch 333/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0499
# Epoch 334/400
# 50/50 [==============================] - 0s 825us/step - loss: 0.0489
# Epoch 335/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0481
# Epoch 336/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0477
# Epoch 337/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0467
# Epoch 338/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0457
# Epoch 339/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0460
# Epoch 340/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0449
# Epoch 341/400
# 50/50 [==============================] - 0s 859us/step - loss: 0.0441
# Epoch 342/400
# 50/50 [==============================] - 0s 858us/step - loss: 0.0437
# Epoch 343/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0429
# Epoch 344/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0424
# Epoch 345/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0417
# Epoch 346/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0413
# Epoch 347/400
# 50/50 [==============================] - 0s 868us/step - loss: 0.0404
# Epoch 348/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0398
# Epoch 349/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0392
# Epoch 350/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0386
# Epoch 351/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0382
# Epoch 352/400
# 50/50 [==============================] - 0s 875us/step - loss: 0.0377
# Epoch 353/400
# 50/50 [==============================] - 0s 931us/step - loss: 0.0372
# Epoch 354/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0363
# Epoch 355/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0359
# Epoch 356/400
# 50/50 [==============================] - 0s 870us/step - loss: 0.0355
# Epoch 357/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0348
# Epoch 358/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0346
# Epoch 359/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0338
# Epoch 360/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.0332
# Epoch 361/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0329
# Epoch 362/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0325
# Epoch 363/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0321
# Epoch 364/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0314
# Epoch 365/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.0312
# Epoch 366/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0306
# Epoch 367/400
# 50/50 [==============================] - 0s 875us/step - loss: 0.0300
# Epoch 368/400
# 50/50 [==============================] - 0s 846us/step - loss: 0.0298
# Epoch 369/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0295
# Epoch 370/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0289
# Epoch 371/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0285
# Epoch 372/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0281
# Epoch 373/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0278
# Epoch 374/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0276
# Epoch 375/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0269
# Epoch 376/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0268
# Epoch 377/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0264
# Epoch 378/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0258
# Epoch 379/400
# 50/50 [==============================] - 0s 936us/step - loss: 0.0255
# Epoch 380/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0251
# Epoch 381/400
# 50/50 [==============================] - 0s 957us/step - loss: 0.0248
# Epoch 382/400
# 50/50 [==============================] - ETA: 0s - loss: 0.018 - 0s 1ms/step - loss: 0.0245
# Epoch 383/400
# 50/50 [==============================] - 0s 896us/step - loss: 0.0242
# Epoch 384/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0239
# Epoch 385/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0237
# Epoch 386/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0233
# Epoch 387/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0229
# Epoch 388/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0227
# Epoch 389/400
# 50/50 [==============================] - 0s 835us/step - loss: 0.0224
# Epoch 390/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0220
# Epoch 391/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0219
# Epoch 392/400
# 50/50 [==============================] - 0s 916us/step - loss: 0.0217
# Epoch 393/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0212
# Epoch 394/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0210
# Epoch 395/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0208
# Epoch 396/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0206A: 0s - loss: 0.020
# Epoch 397/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0202
# Epoch 398/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0201
# Epoch 399/400
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0199
# Epoch 400/400
# 50/50 [==============================] - 0s 977us/step - loss: 0.0196

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.losses import MeanSquaredError

#calculate loss axis
mse = keras.losses.MeanSquaredError()


#decide how many points we want to plot on each axis
n = 20

#decide which node we should modify
node_index = 0

#which values of weights did we optimize to 
optimized_weights = model.get_weights()
optimized_beta = optimized_weights[0][0][node_index]
optimized_alpha = optimized_weights[2][node_index][0]

#look at area around the optimized parameters
beta_axis = np.linspace(optimized_beta - 1,optimized_beta + 1,n)
alpha_axis = np.linspace(optimized_alpha - 1, optimized_alpha + 1,n)

Beta_axis, Alpha_axis = np.array(np.meshgrid(beta_axis, alpha_axis))

#Create a new variable with the same structure as Beta_axis
import copy
Loss_axis = copy.deepcopy(Beta_axis)


for i in range(n):
    for j in range(n):
    
        beta_plot = Beta_axis[i][j]
        alpha_plot = Alpha_axis[i][j]
        
        weights = copy.deepcopy(optimized_weights)
        
        weights[0][0][node_index] = beta_plot
        weights[2][node_index][0] = alpha_plot
        
        model.set_weights(weights)
        
        y_pred = model.predict(X_data)
        
        
        #now note that y_data is a row vector, while predictions is a column vector. So first we have to adjust the format:
        #y_data = [.. , .. , .. , ...]  while 
        #predictions = [[..],[..],[..], ...]

        #let predictions have the same format as y_data
        [y_pred] = y_pred.transpose()
        
       
        Loss_axis[i][j] = mse(y_data, y_pred).numpy()
        

#draw the contour plot
vmin = 0
vmax = 0.2
levels = np.linspace(vmin, vmax, 500 + 1)

plt.ylabel('alpha-values')
plt.xlabel('beta-values')
plt.contourf(Beta_axis, Alpha_axis,Loss_axis , 500, cmap='RdGy', levels=levels)
plt.colorbar()

# %%
#lambda_val =! 0
lambda_val = 3

#which node will be modify?
node_index = 0


#modify the NN as explained

#copy the values of the weights
import copy
optimized = copy.deepcopy(optimized_weights)

#change the alpha value (alpha_i):
optimized[2][node_index][0] = 1/lambda_val * optimized[2][node_index][0] 

#change the beta value (beta_i)
optimized[0][0][node_index] = lambda_val * optimized[0][0][node_index]

#change the b value:
optimized[1][node_index] = lambda_val * optimized[1][node_index]


#we will use this function later to calculate the loss
mse = keras.losses.MeanSquaredError()


#decide how many points we want to plot on each axis
n = 20

#get the modified weights
optimized_beta = optimized[0][0][node_index]
optimized_alpha = optimized[2][node_index][0]

#plot a grid around the point of the optimized weights
beta_axis = np.linspace(optimized_beta - 1,optimized_beta + 1,n)
alpha_axis = np.linspace(optimized_alpha - 1, optimized_alpha + 1,n)

Beta_axis, Alpha_axis = np.array(np.meshgrid(beta_axis, alpha_axis))

#Create a new variable with the same structure as Beta_axis
import copy
Loss_axis = copy.deepcopy(Beta_axis)


for i in range(n):
    for j in range(n):
    
        beta_plot = Beta_axis[i][j]
        alpha_plot = Alpha_axis[i][j]
        
        weights = copy.deepcopy(optimized)
        
        weights[0][0][node_index] = beta_plot
        weights[2][node_index][0] = alpha_plot
        
        model.set_weights(weights)
        
        y_pred = model.predict(X_data)
        
        
        #now note that y_data is a row vector, while predictions is a column vector. So first we have to adjust the format:
        #y_data = [.. , .. , .. , ...]  while 
        #predictions = [[..],[..],[..], ...]

        #let predictions have the same format as y_data
        [y_pred] = y_pred.transpose()
        
        #calculate the loss and save it
        Loss_axis[i][j] = mse(y_data, y_pred).numpy()
        

#draw the contour plot
vmin = 0
vmax = 0.2
levels = np.linspace(vmin, vmax, 500 + 1)

plt.ylabel('alpha-values')
plt.xlabel('beta-values')
plt.contourf(Beta_axis, Alpha_axis,Loss_axis , 500, cmap='RdGy', levels=levels)
plt.colorbar()

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
