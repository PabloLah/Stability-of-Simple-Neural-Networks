# %%
#generating random data from a linear function and adding noise
#generate x-values uniformly inside the interval [0,1]
import numpy as np
X_data = np.random.uniform(0, 1, 1000)

#generate noise with normal distribution
noise = np.random.normal(0, 0.1, X_data.size)

#generate values of the linear function: f(x) = alpha_prime * x
#and add the noise
alpha_prime = 2
y_data = alpha_prime * X_data + noise


#building the model
#import the necessary functions from the tensorflow library
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#introduce the learning model: one hidden layer and one hidden node
model = Sequential()
model.add(Dense(1, input_dim=1, activation='relu', use_bias=True))
model.add(Dense(1, activation='linear', use_bias=True))


#compile the model
model.compile(loss='mean_squared_error', optimizer='SGD')

#fit the model to our data
model.fit(X_data, y_data, epochs=50, batch_size=20)


#evaluate the model
predictions = model.predict(X_data)

import matplotlib.pyplot as plt

plt.clf()
plt.plot(X_data,y_data,'.')
plt.plot(X_data,predictions,'.')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.show()
# Out:
# Epoch 1/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8151
# Epoch 2/50
# 50/50 [==============================] - 0s 936us/step - loss: 0.4144
# Epoch 3/50
# 50/50 [==============================] - 0s 905us/step - loss: 0.3596
# Epoch 4/50
# 50/50 [==============================] - 0s 920us/step - loss: 0.3518
# Epoch 5/50
# 50/50 [==============================] - 0s 958us/step - loss: 0.3506
# Epoch 6/50
# 50/50 [==============================] - 0s 920us/step - loss: 0.3505
# Epoch 7/50
# 50/50 [==============================] - 0s 918us/step - loss: 0.3506
# Epoch 8/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3507
# Epoch 9/50
# 50/50 [==============================] - 0s 997us/step - loss: 0.3504
# Epoch 10/50
# 50/50 [==============================] - 0s 955us/step - loss: 0.3505
# Epoch 11/50
# 50/50 [==============================] - 0s 959us/step - loss: 0.3505
# Epoch 12/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3506
# Epoch 13/50
# 50/50 [==============================] - 0s 922us/step - loss: 0.3505
# Epoch 14/50
# 50/50 [==============================] - 0s 878us/step - loss: 0.3505
# Epoch 15/50
# 50/50 [==============================] - 0s 924us/step - loss: 0.3504
# Epoch 16/50
# 50/50 [==============================] - 0s 875us/step - loss: 0.3504
# Epoch 17/50
# 50/50 [==============================] - 0s 855us/step - loss: 0.3505
# Epoch 18/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 19/50
# 50/50 [==============================] - 0s 880us/step - loss: 0.3504
# Epoch 20/50
# 50/50 [==============================] - 0s 918us/step - loss: 0.3504
# Epoch 21/50
# 50/50 [==============================] - 0s 902us/step - loss: 0.3505
# Epoch 22/50
# 50/50 [==============================] - 0s 957us/step - loss: 0.3504
# Epoch 23/50
# 50/50 [==============================] - 0s 905us/step - loss: 0.3506
# Epoch 24/50
# 50/50 [==============================] - 0s 977us/step - loss: 0.3505
# Epoch 25/50
# 50/50 [==============================] - 0s 873us/step - loss: 0.3504
# Epoch 26/50
# 50/50 [==============================] - 0s 978us/step - loss: 0.3505
# Epoch 27/50
# 50/50 [==============================] - 0s 977us/step - loss: 0.3504
# Epoch 28/50
# 50/50 [==============================] - 0s 977us/step - loss: 0.3504
# Epoch 29/50
# 50/50 [==============================] - 0s 977us/step - loss: 0.3506
# Epoch 30/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 31/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 32/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 33/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3504
# Epoch 34/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3507
# Epoch 35/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 36/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 37/50
# 50/50 [==============================] - 0s 916us/step - loss: 0.3505
# Epoch 38/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3504
# Epoch 39/50
# 50/50 [==============================] - 0s 896us/step - loss: 0.3505
# Epoch 40/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 41/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3505
# Epoch 42/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 43/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3506
# Epoch 44/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.3503
# Epoch 45/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 46/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3506
# Epoch 47/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3504
# Epoch 48/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3505
# Epoch 49/50
# 50/50 [==============================] - 0s 997us/step - loss: 0.3505
# Epoch 50/50
# 50/50 [==============================] - 0s 936us/step - loss: 0.3505
