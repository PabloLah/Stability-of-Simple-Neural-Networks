# %%
#Note: We program a simple NN to interpolate a linear function.


#generating random data from a linear function and adding noise
#generate x-values uniformly inside the interval [0,1]
import numpy as np
X_data = np.random.uniform(0, 1, 1000)

#generate noise with normal distribution
noise = np.random.normal(0, 0.1, X_data.size)

#generate values of the linear function: f(x) = alpha_prime * x
#and add the noise
alpha_prime = 2
y_data = alpha_prime * X_data + noise


#building the model
#import the necessary functions from the tensorflow library
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#introduce the learning model: one hidden layer and one hidden node
model = Sequential()
model.add(Dense(1, input_dim=1, activation='relu', use_bias=True))
model.add(Dense(1, activation='linear', use_bias=True))


#compile the model
model.compile(loss='mean_squared_error', optimizer='SGD')

#fit the model to our data
model.fit(X_data, y_data, epochs=50, batch_size=20)


#evaluate the model
predictions = model.predict(X_data)

import matplotlib.pyplot as plt

plt.clf()
plt.plot(X_data,y_data,'.')
plt.plot(X_data,predictions,'.')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.show()
# Out:
# Epoch 1/50
# 50/50 [==============================] - 1s 2ms/step - loss: 0.5559
# Epoch 2/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1616
# Epoch 3/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.1216
# Epoch 4/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0970
# Epoch 5/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0757
# Epoch 6/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0579
# Epoch 7/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0439
# Epoch 8/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0335
# Epoch 9/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0260
# Epoch 10/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0208
# Epoch 11/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 12/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0147
# Epoch 13/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 14/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 15/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0110
# Epoch 16/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0104
# Epoch 17/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 18/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0098
# Epoch 19/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 20/50
# 50/50 [==============================] - ETA: 0s - loss: 0.009 - 0s 2ms/step - loss: 0.0095
# Epoch 21/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 22/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0094
# Epoch 23/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 24/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 25/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 26/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 27/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 28/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 29/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 30/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 31/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 32/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 33/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 34/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 35/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 36/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 37/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 38/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 39/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 40/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 41/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 42/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 43/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 44/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 45/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 46/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 47/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 48/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 49/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 50/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.0091

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
import matplotlib.pyplot as plt

#set fixed values for alpha and h
b_plot = 0
h_plot = 0



from tensorflow import keras
from keras.losses import MeanSquaredError

#calculate loss axis
mse = keras.losses.MeanSquaredError()

#generate the points on each axis
n=20
beta_axis = np.linspace(0,4,n)
alpha_axis = np.linspace(0,4,n)

#plot the grid of points from which we will compute the loss
Beta_axis, Alpha_axis = np.array(np.meshgrid(beta_axis, alpha_axis))

#Create a new variable with the same structure as Beta_axis
import copy
Loss_axis = copy.deepcopy(Beta_axis)


for i in range(n):
    for j in range(n):
    
        beta_plot = Beta_axis[i][j]
        alpha_plot = Alpha_axis[i][j]
        
        model.set_weights([np.array([[beta_plot]]), np.array([b_plot]), np.array([[alpha_plot]]), np.array([h_plot])])
        
        y_pred = model.predict(X_data)
        
        #now note that y_data is a row vector, while predictions is a column vector. So first we have to adjust the format:
        #y_data = [.. , .. , .. , ...]  while 
        #predictions = [[..],[..],[..], ...]

        #let predictions have the same format as y_data
        [y_pred] = y_pred.transpose()
        
        #save the values of the loss
        Loss_axis[i][j] = mse(y_data, y_pred).numpy()
        

#draw the contour plot
vmin = 0
vmax = 0.5
levels = np.linspace(vmin, vmax, 500 + 1)

plt.ylabel('alpha-values')
plt.xlabel('beta-values')
plt.contourf(Beta_axis, Alpha_axis,Loss_axis , 500, cmap='RdGy', levels=levels)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21656/389066318.py in <module>
#      35         model.set_weights([np.array([[beta_plot]]), np.array([b_plot]), np.array([[alpha_plot]]), np.array([h_plot])])
#      36
# ---> 37         y_pred = model.predict(X_data)
#      38
#      39         #now note that y_data is a row vector, while predictions is a column vector. So first we have to adjust the format:
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1756               stacklevel=2)
#    1757
# -> 1758       data_handler = data_adapter.get_data_handler(
#    1759           x=x,
#    1760           batch_size=batch_size,
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1401   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1402     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1403   return DataHandler(*args, **kwargs)
#    1404
#    1405
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1151
#    1152     adapter_cls = select_data_adapter(x, y)
# -> 1153     self._adapter = adapter_cls(
#    1154         x,
#    1155         y,
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     325     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     326
# --> 327     dataset = self.slice_inputs(indices_dataset, inputs)
#     328
#     329     if shuffle == "batch":
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     357       return tf.nest.map_structure(lambda d: tf.gather(d, i, axis=0), data)
#     358
# --> 359     dataset = dataset.map(
#     360         grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     361
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2004       return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2005     else:
# -> 2006       return ParallelMapDataset(
#    2007           self,
#    2008           map_func,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5499     self._input_dataset = input_dataset
#    5500     self._use_inter_op_parallelism = use_inter_op_parallelism
# -> 5501     self._map_func = StructuredFunctionWrapper(
#    5502         map_func,
#    5503         self._transformation_name(),
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4531         fn_factory = trace_tf_function(defun_kwargs)
#    4532
# -> 4533     self._function = fn_factory()
#    4534     # There is no graph to add in eager mode.
#    4535     add_to_graph &= not context.executing_eagerly()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    3242          or `tf.Tensor` or `tf.TensorSpec`.
#    3243     """
# -> 3244     graph_function = self._get_concrete_function_garbage_collected(
#    3245         *args, **kwargs)
#    3246     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3208       args, kwargs = None, None
#    3209     with self._lock:
# -> 3210       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3211       seen_names = set()
#    3212       captured = object_identity.ObjectIdentitySet(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3389     ]
#    3390     arg_names = base_arg_names + missing_arg_names
# -> 3391     graph_function = ConcreteFunction(
#    3392         func_graph_module.func_graph_from_py_func(
#    3393             self._name,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __init__(self, func_graph, attrs, shared_func_graph, function_spec)
#    1591     # These each get a reference to the FuncGraph deleter since they use the
#    1592     # FuncGraph directly.
# -> 1593     self._delayed_rewrite_functions = _DelayedRewriteGradientFunctions(
#    1594         func_graph, self._attrs, self._garbage_collector)
#    1595     self._first_order_tape_functions = {}
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __init__(self, func_graph, attrs, func_graph_deleter)
#     681     self._cached_function_pairs = {}
#     682     self._func_graph = func_graph
# --> 683     self._inference_function = _EagerDefinedFunction(
#     684         _inference_name(self._func_graph.name), self._func_graph,
#     685         self._func_graph.inputs, self._func_graph.outputs, attrs)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __init__(self, name, graph, inputs, outputs, attrs)
#     474     else:
#     475       output_names = []
# --> 476     fn = pywrap_tf_session.TF_GraphToFunction_wrapper(
#     477         graph._c_graph,  # pylint: disable=protected-access
#     478         compat.as_str(name),
#
# KeyboardInterrupt:

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
#this is only relevant if we want to add another cntour plot to the report.



import numpy as np
import matplotlib.pyplot as plt

#set fixed values for alpha and h
b_plot = 0
h_plot = 0



from tensorflow import keras
from keras.losses import MeanSquaredError

#calculate loss axis
mse = keras.losses.MeanSquaredError()

#generate the points on each axis
n=20
beta_axis = np.linspace(0,4,n)
alpha_axis = np.linspace(0,4,n)

#plot the grid of points from which we will compute the loss
Beta_axis, Alpha_axis = np.array(np.meshgrid(beta_axis, alpha_axis))

#Create a new variable with the same structure as Beta_axis
import copy
Loss_axis = copy.deepcopy(Beta_axis)


for i in range(n):
    for j in range(n):
    
        beta_plot = Beta_axis[i][j]
        alpha_plot = Alpha_axis[i][j]
        
        model.set_weights([np.array([[beta_plot]]), np.array([b_plot]), np.array([[alpha_plot]]), np.array([h_plot])])
        
        y_pred = model.predict(X_data)
        
        #now note that y_data is a row vector, while predictions is a column vector. So first we have to adjust the format:
        #y_data = [.. , .. , .. , ...]  while 
        #predictions = [[..],[..],[..], ...]

        #let predictions have the same format as y_data
        [y_pred] = y_pred.transpose()
        
        #save the values of the loss
        Loss_axis[i][j] = mse(y_data, y_pred).numpy()
        

#draw the contour plot
vmin = 0
vmax = 0.5
levels = np.linspace(vmin, vmax, 500 + 1)

plt.ylabel('alpha-values')
plt.xlabel('beta-values')
plt.contourf(Beta_axis, Alpha_axis,Loss_axis , 500, cmap='RdGy', levels=levels)
plt.colorbar()
